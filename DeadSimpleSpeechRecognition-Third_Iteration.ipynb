# %%
# %load_ext autoreload
# %autoreload 2

from preprocess import *
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.utils import to_categorical

# Second dimension of the feature is dim2
feature_dim_2 = 11

# Save data to array file first
save_data_to_array(max_len=feature_dim_2)

# # Loading train set and test set
X_train, X_test, y_train, y_test = get_train_test()

# # Feature dimension
feature_dim_1 = 20
channel = 1
epochs = 150
batch_size = 100
verbose = 1
num_classes = 2

# Reshaping to perform 2D convolution
X_train = X_train.reshape(X_train.shape[0], feature_dim_1, feature_dim_2, channel)
X_test = X_test.reshape(X_test.shape[0], feature_dim_1, feature_dim_2, channel)

y_train_hot = to_categorical(y_train)
y_test_hot = to_categorical(y_test)
# Out:
# Saving vectors of label - 'other':   0%|          | 0/201 [00:00<?, ?it/s]
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ...
# Saving vectors of label - 'Chopin': 100%|██████████| 208/208 [04:53<00:00,  1.41s/it]

# %%
def get_model():
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(2, 2), activation='relu', input_shape=(feature_dim_1, feature_dim_2, channel)))
    model.add(Conv2D(48, kernel_size=(2, 2), activation='relu'))
    model.add(Conv2D(120, kernel_size=(2, 2), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
    return model

# Predicts one sample
def predict(filepath, model):
    sample = wav2mfcc(filepath)
    sample_reshaped = sample.reshape(1, feature_dim_1, feature_dim_2, channel)
    return get_labels()[0][
            np.argmax(model.predict(sample_reshaped))
    ]

# %% [markdown]
# # Building The Model Then Training it

# %%
model = get_model()
model.fit(X_train, y_train_hot, batch_size=batch_size, epochs=epochs, verbose=verbose, validation_data=(X_test, y_test_hot))
# Out:
# Train on 245 samples, validate on 164 samples
# Epoch 1/150
# 245/245 [==============================] - 1s 3ms/step - loss: 2.7914 - acc: 0.5306 - val_loss: 0.7858 - val_acc: 0.5305
# Epoch 2/150
# 245/245 [==============================] - 0s 525us/step - loss: 1.0078 - acc: 0.5510 - val_loss: 0.6419 - val_acc: 0.6768
# Epoch 3/150
# 245/245 [==============================] - 0s 477us/step - loss: 0.9195 - acc: 0.5306 - val_loss: 0.6554 - val_acc: 0.5305
# Epoch 4/150
# 245/245 [==============================] - 0s 468us/step - loss: 0.7816 - acc: 0.5347 - val_loss: 0.6063 - val_acc: 0.6707
# Epoch 5/150
# 245/245 [==============================] - 0s 477us/step - loss: 0.7325 - acc: 0.6245 - val_loss: 0.6024 - val_acc: 0.6646
# Epoch 6/150
# 245/245 [==============================] - 0s 476us/step - loss: 0.6368 - acc: 0.6857 - val_loss: 0.5995 - val_acc: 0.6890
# Epoch 7/150
# ...

# %%
model.fit(X_train, y_train_hot, batch_size=batch_size, epochs=100, verbose=verbose, validation_data=(X_test, y_test_hot))
# Out:
# Train on 245 samples, validate on 164 samples
# Epoch 1/100
# 245/245 [==============================] - 0s 553us/step - loss: 0.2436 - acc: 0.8816 - val_loss: 1.7174 - val_acc: 0.7073
# Epoch 2/100
# 245/245 [==============================] - 0s 511us/step - loss: 0.2388 - acc: 0.8816 - val_loss: 1.6152 - val_acc: 0.7195
# Epoch 3/100
# 245/245 [==============================] - 0s 514us/step - loss: 0.2388 - acc: 0.8857 - val_loss: 1.7763 - val_acc: 0.7134
# Epoch 4/100
# 245/245 [==============================] - 0s 473us/step - loss: 0.2349 - acc: 0.8776 - val_loss: 1.7018 - val_acc: 0.7195
# Epoch 5/100
# 245/245 [==============================] - 0s 476us/step - loss: 0.2494 - acc: 0.8735 - val_loss: 1.8316 - val_acc: 0.7134
# Epoch 6/100
# 245/245 [==============================] - 0s 479us/step - loss: 0.2413 - acc: 0.8816 - val_loss: 2.0902 - val_acc: 0.6707
# Epoch 7/100
# ...

# %%
model.fit(X_train, y_train_hot, batch_size=batch_size, epochs=500, verbose=verbose, validation_data=(X_test, y_test_hot))
# Out:
# Train on 245 samples, validate on 164 samples
# Epoch 1/500
# 245/245 [==============================] - 0s 560us/step - loss: 0.2249 - acc: 0.8939 - val_loss: 2.1804 - val_acc: 0.7073
# Epoch 2/500
# 245/245 [==============================] - 0s 474us/step - loss: 0.2144 - acc: 0.8980 - val_loss: 2.1744 - val_acc: 0.7256
# Epoch 3/500
# 245/245 [==============================] - 0s 455us/step - loss: 0.2278 - acc: 0.8980 - val_loss: 2.1671 - val_acc: 0.7378
# Epoch 4/500
# 245/245 [==============================] - 0s 459us/step - loss: 0.2142 - acc: 0.8939 - val_loss: 2.2161 - val_acc: 0.7317
# Epoch 5/500
# 245/245 [==============================] - 0s 475us/step - loss: 0.2256 - acc: 0.8898 - val_loss: 2.1094 - val_acc: 0.7500
# Epoch 6/500
# 245/245 [==============================] - 0s 481us/step - loss: 0.2213 - acc: 0.8857 - val_loss: 2.1062 - val_acc: 0.7500
# Epoch 7/500
# ...

# %% [markdown]
# ## Prediction

# %%
print(predict('./test/other_test (6).mp3', model=model))
# Out:
# Chopin

# %%
import glob
for i in glob.glob('./test/*.mp3'):
    print("{0} is {1}".format(i,predict(i, model=model)))
# Out:
# ./test/other_test (1).mp3 is Chopin
# ./test/other_test (3).mp3 is Chopin
# ./test/Kevin Kern - wave.mp3 is other
# ./test/other_test (2).mp3 is other
# ./test/Kevin Kern - We Should Waltz.mp3 is other
# ./test/other_test (6).mp3 is Chopin
# ./test/other_test (4).mp3 is Chopin
# ./test/other_test (8).mp3 is Chopin
# ./test/other_test (5).mp3 is Chopin
# ./test/Kevin Kern - Le Jardin.mp3 is Chopin

# %%
count_chopin = 0
for i in glob.glob('./chopin_test/*.mp3'):
    label =  predict(i, model=model)
    if label == "Chopin":
        count_chopin += 1
    print("Chopin Prediction is {0}".format(predict(i, model=model)))
# Out:
# Chopin Prediction is other
# Chopin Prediction is other
# Chopin Prediction is Chopin
# Chopin Prediction is other
# Chopin Prediction is Chopin
# Chopin Prediction is Chopin
# Chopin Prediction is other
# Chopin Prediction is Chopin
# Chopin Prediction is Chopin
# Chopin Prediction is Chopin
# Chopin Prediction is other
# Chopin Prediction is other
# Chopin Prediction is Chopin
# Chopin Prediction is Chopin
# Chopin Prediction is Chopin
# Chopin Prediction is Chopin
# Chopin Prediction is other
# Chopin Prediction is other

# %%
blind_acc_chopin = count_chopin/len(glob.glob('./chopin_test/*.mp3'))
blind_acc_chopin
# Out:
# 0.5555555555555556

# %%
count_other = 0
for i in glob.glob('./Other_Musician/*.mp3'):
    label =  predict(i, model=model)
    if label == "other":
        count_other += 1
    print("Other Prediction is {0}".format(label))
# Out:
# Other Prediction is other
# Other Prediction is Chopin
# Other Prediction is other
# Other Prediction is Chopin
# Other Prediction is Chopin
# Other Prediction is other
# Other Prediction is Chopin
# Other Prediction is Chopin
# Other Prediction is other
# Other Prediction is Chopin
# Other Prediction is Chopin
# Other Prediction is other
# Other Prediction is Chopin
# Other Prediction is Chopin
# Other Prediction is other
# Other Prediction is Chopin
# Other Prediction is Chopin
# Other Prediction is Chopin
# Other Prediction is Chopin
# Other Prediction is other
# Other Prediction is Chopin
# Other Prediction is other
# Other Prediction is other
# Other Prediction is Chopin
# Other Prediction is Chopin
# Other Prediction is Chopin
# Other Prediction is other
# Other Prediction is other
# Other Prediction is Chopin
# Other Prediction is other
# Other Prediction is Chopin
# Other Prediction is Chopin
# Other Prediction is Chopin
# Other Prediction is other
# ...

# %%
len(glob.glob('./Other_Musician/*.mp3'))
# Out:
# 57

# %%
blind_acc = count_other/len(glob.glob('./Other_Musician/*.mp3'))
blind_acc
# Out:
# 0.3508771929824561

# %%
count_liszt = 0
for i in glob.glob('./liszt_test/*.mp3'):
    label =  predict(i, model=model)
    if label == "other":
        count_liszt += 1
    print("Liszt Prediction is {0}".format(label))
# Out:
# Liszt Prediction is Chopin
# Liszt Prediction is Chopin
# Liszt Prediction is Chopin
# Liszt Prediction is other
# Liszt Prediction is other
# Liszt Prediction is other
# Liszt Prediction is Chopin
# Liszt Prediction is Chopin
# Liszt Prediction is Chopin
# Liszt Prediction is other
# Liszt Prediction is Chopin
# Liszt Prediction is Chopin
# Liszt Prediction is Chopin

# %%
blind_acc_lis = count_liszt/len(glob.glob('./liszt_test/*.mp3'))
blind_acc_lis
# Out:
# 0.3076923076923077
